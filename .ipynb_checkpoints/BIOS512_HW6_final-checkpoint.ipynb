# %% [markdown]
# # Homework 6
# This homework builds on the effective visualization workshop with the Star Trek data. Below is what we completed in class. Output is suppressed for readability, but you can remove the supression on your code if you'd like.

# %%
library(tidyverse)

# Get the data.
dialogs <- read_csv(
  "https://raw.githubusercontent.com/Vincent-Toups/bios512/fcbc65a2696c7cff80d0f6ed1dd5c97abf0ef800/effective-visualization/source_data/tng.csv",
  show_col_types = FALSE
)
head(dialogs, 10) # Showing first 10 observations

# Checkout the data.
names(dialogs)
dialogs %>% group_by(character) %>% tally() %>% arrange(desc(n))
dialogs %>% mutate(dialog_length=str_length(dialog)) %>% group_by(character) %>% summarize(mean_dialog_length = mean(dialog_length)) %>% arrange(desc(mean_dialog_length))

# Fix weird data.
dialogs %>% filter(character=="BEVERLY'S")

dialogs_fixed <- dialogs %>%
  mutate(
    character = str_replace_all(character, "'S.*$", ""),
    character = str_replace_all(character, " VOICE", ""),
    character = str_replace_all(character, "\\.", ""),
    character = str_replace_all(character, "'", ""),
    character = str_replace_all(character, "S COM", ""),
    character = str_replace_all(character, " COM", ""),
    dialog_length = str_length(dialog)
  ) %>%
  filter(character %in% unlist(str_split("PICARD RIKER DATA TROI BEVERLY WORF WESLEY GEORDI", " ")))

dialogs_fixed %>% group_by(character) %>% summarize(mean_dialog_length = mean(dialog_length), std_dialog_length=sd(dialog_length)) %>% arrange(desc(mean_dialog_length))

dialog_len_per_ep <- dialogs_fixed %>% group_by(character, episode_number) %>% summarize(mean_dialog_length = mean(dialog_length), std_dialog_length=sd(dialog_length), .groups = "drop") %>% arrange(desc(mean_dialog_length))

dialog_len_per_ep

# Plot the data.
ggplot(dialogs_fixed) + geom_density(aes(x=dialog_length))

for_factor <- dialog_len_per_ep %>% group_by(character) %>% summarise(m=mean(mean_dialog_length)) %>% arrange(desc(m))
ggplot(dialog_len_per_ep, aes(factor(character,for_factor$character), mean_dialog_length)) + geom_boxplot()

dialog_len_per_ep <- dialogs_fixed %>% 
    group_by(character, episode_number) %>% 
    summarize(mean_dialog_length = mean(dialog_length), dialog_count=n(), .groups = "drop") %>% 
    arrange(desc(mean_dialog_length))

ggplot(dialog_len_per_ep, aes(dialog_count, mean_dialog_length)) + geom_point(aes(color=character)) + facet_wrap(~character)
# Out:
#    episode_number character
# 1  102            PICARD
# 2  102            PICARD
# 3  102            PICARD
# 4  102            PICARD
# 5  102            PICARD
# 6  102            PICARD
# 7  102            PICARD
# 8  102            DATA
# 9  102            PICARD
# 10 102            TROI
#    dialog
# 1  Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 2  My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 3  ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# 4  I am still somewhat in awe of its size and complexity.
# 5  ... my crew we are short in several key positions, most notably ...
# 6  ... a first officer, but I am informed that a highly experienced man, one Commander William Riker, will be waiting to join our ship when we reach our Cygnus IV destination.
# 7  You will agree, Data, that Starfleet's instructions are difficult?
# 8  Difficult ... how so? Simply solve the mystery of Farpoint Station.
# 9  As simple as that.
# 10 Farpoint Station. Even the name sounds mysterious.
# [1] "episode_number" "character"      "dialog"
#     character                 n
# 1   PICARD                    15180
# 2   RIKER                      8843
# 3   DATA                       7390
# 4   GEORDI                     5498
# 5   WORF                       4429
# 6   BEVERLY                    4035
# 7   TROI                       3922
# 8   WESLEY                     1664
# 9   PULASKI                     705
# 10  TASHA                       615
# 11  GUINAN                      610
# 12  Q                           573
# 13  O'BRIEN                     551
# 14  COMPUTER VOICE              505
# 15  RO                          458
# 16  BARCLAY                     421
# 17  LWAXANA                     385
# 18  VASH                        225
# 19  ALEXANDER                   221
# 20  K'EHLEYR                    221
# 21  JELLICO                     202
# 22  LORE                        183
# 23  MORIARTY                    182
# 24  MRS. TROI                   165
# 25  SOREN                       155
# 26  AMANDA                      140
# 27  GOWRON                      139
# 28  LT. RIKER                   137
# 29  SCOTT                       137
# 30  KURN                        131
# ⋮   ⋮                         ⋮
# 885 PICARD.                   1
# 886 PORTAL FIGURE             1
# 887 Q SHADOW                  1
# 888 RIKER AND TASHA           1
# 889 RIKER'S COMM VOICE        1
# 890 RISON                     1
# 891 RONIN VOICE               1
# 892 SANTOS' COM VOICE         1
# 893 SECOND EDO BOY            1
# 894 SECOND LEADER             1
# 895 SECURITY GUARD COM VOICE  1
# 896 SECURITY MAN              1
# 897 SERGANT                   1
# 898 SUPERNUMERARY             1
# 899 TARRANA                   1
# 900 TEMAREK                   1
# 901 THE ALIEN                 1
# 902 THE GROUP                 1
# 903 TOYA                      1
# 904 TRANSPORTER CHIEF'S VOICE 1
# 905 TRANSPORTER OPERATOR      1
# 906 TRANSPORTER TECHNICIAN    1
# 907 TYLER'S VOICE             1
# 908 VOVAL                     1
# 909 WAGNOR                    1
# 910 WEAK VOICE                1
# 911 WESLEY COM VOICE          1
# 912 WOUNDED CREWMEMBER        1
# 913 YOUNG REPOTER             1
# 914 YOUNG RIKER               1
#     character               mean_dialog_length
# 1   BEVERLY'S               243.0000
# 2   MAXWELL AND O'BRIEN     226.0000
# 3   CAPTAIN ZAHEVA          225.0000
# 4   HOLO SPOCK              221.0000
# 5   HUMANOID                216.5000
# 6   ANTHARWA                195.0000
# 7   END OF TEASER           187.0000
# 8   END OF ACT ONE          185.0000
# 9   VARLEY                  181.2000
# 10  ADMIRAL BRACKETT        172.6667
# 11  KWAN'S VOICE            169.0000
# 12  SHELIAK VOICE           167.0000
# 13  CONNAUGHT               163.5000
# 14  DUANE                   161.0000
# 15  O'BRIEN'S VOICE         160.0000
# 16  HAFTEL                  157.5000
# 17  ADMIRAL HADEN           149.5000
# 18  MALE VOICE              144.3333
# 19  GEORI                   143.0000
# 20  JARALAN                 143.0000
# 21  BATES                   142.5000
# 22  ACT ONE                 142.0000
# 23  INDIANS                 142.0000
# 24  TOQ'S VOICE             141.0000
# 25  ANTHWARA                137.2273
# 26  HOLO-SUSANNA            127.0000
# 27  MALE COM VOICE          125.5000
# 28  HOLO-LEAH               123.0000
# 29  TAGGERT                 121.5000
# 30  PICARD'S RECORDED VOICE 119.0000
# ⋮   ⋮                       ⋮
# 885 RIKER AND TASHA         15.00000
# 886 VOLNOTH                 14.66667
# 887 HOLO-WESLEY             14.33333
# 888 ENSIGN CRAIG            14.00000
# 889 JACK'S VOICE            14.00000
# 890 PICARD.                 14.00000
# 891 SALAZAR'S VOICE         13.50000
# 892 AIDE                    13.00000
# 893 AMERICAN INDIAN         13.00000
# 894 PICARD'S INTERCOM VOICE 12.00000
# 895 SKORAN'S VOICE          12.00000
# 896 KORAL                   11.20000
# 897 BENSON                  11.00000
# 898 KELLER                  11.00000
# 899 MAURICE'S VOICE         11.00000
# 900 N.D.                    11.00000
# 901 YOUNG RIKER             11.00000
# 902 ALEXANDRA               10.50000
# 903 ANNA'S VOICE            10.00000
# 904 CRUSHER                 10.00000
# 905 KAMALA'S VOICE          10.00000
# 906 N.D. VOICE              10.00000
# 907 CON OFFICER'S VOICE      9.00000
# 908 GAINES' COM VOICE        9.00000
# 909 BOY                      7.00000
# 910 DATA FRANK               7.00000
# 911 TARRANA                  7.00000
# 912 MOLLY'S VOICE            6.00000
# 913 JONO'S VOICE             5.00000
# 914 KAHLESS' VOICE           5.00000
#   episode_number character
# 1 253            BEVERLY'S
#   dialog
# 1 Acting Captain's Log, Supplemental: The skeleton crew left on board the Enterprise is unable to help in the search for Commander Data. The planet's unusual EM field is interfering with the ship's sensors, severely limiting their effectiveness.
#   character mean_dialog_length std_dialog_length
# 1 DATA      69.44862           54.14817
# 2 BEVERLY   61.79965           49.80177
# 3 GEORDI    60.57158           48.48001
# 4 PICARD    57.32696           50.98378
# 5 TROI      56.06494           46.65127
# 6 RIKER     49.76248           42.53393
# 7 WESLEY    47.11038           40.57180
# 8 WORF      47.05002           37.92466
#      character episode_number mean_dialog_length std_dialog_length
# 1    TROI      129            185.5000            40.30509
# 2    GEORDI    249            179.0000                  NA
# 3    BEVERLY   242            158.0000            57.98276
# 4    BEVERLY   159            146.5000            86.97413
# 5    BEVERLY   261            133.5000            20.50610
# 6    BEVERLY   116            129.7143           127.83807
# 7    TROI      135            129.5000            23.33452
# 8    GEORDI    162            129.0000            96.12728
# 9    TROI      199            125.0000            30.65942
# 10   BEVERLY   207            122.5000            75.66043
# 11   DATA      239            121.0000            94.75231
# 12   TROI      123            117.5000            89.80256
# 13   DATA      195            115.2500            68.82223
# 14   DATA      115            113.1562            96.89273
# 15   BEVERLY   164            111.7778            86.44475
# 16   TROI      272            111.5000            69.09173
# 17   DATA      172            110.0000            45.05754
# 18   RIKER     219            109.6667            77.70028
# 19   TROI      144            106.8000            41.82344
# 20   TROI      243            106.0000                  NA
# 21   BEVERLY   249            104.7500            71.12138
# 22   DATA      156            104.6000            69.24573
# 23   TROI      189            104.2500            62.26155
# 24   DATA      270            102.6250            69.72219
# 25   BEVERLY   201            102.5000            84.14571
# 26   DATA      136            102.1333            80.01863
# 27   TROI      264            100.6667            20.84067
# 28   DATA      230            100.3846            52.92975
# 29   TROI      233             98.8000            51.46477
# 30   TROI      187             98.0000            38.68678
# ⋮    ⋮         ⋮              ⋮                  ⋮
# 1229 TROI      181            31.00000                  NA
# 1230 WORF      124            30.26087           23.831258
# 1231 WESLEY    166            30.25000           20.036898
# 1232 PICARD    175            30.10000           28.321370
# 1233 WORF      158            30.03448           20.127243
# 1234 TROI      276            29.75000           15.671099
# 1235 GEORDI    166            29.60000           16.194649
# 1236 WORF      228            29.33333           21.667179
# 1237 WORF      218            29.27273           21.961238
# 1238 WORF      166            29.16667           22.513969
# 1239 GEORDI    240            29.00000            2.828427
# 1240 GEORDI    254            29.00000                  NA
# 1241 WORF      194            28.85714           26.251531
# 1242 BEVERLY   120            28.80000           19.601020
# 1243 WESLEY    173            28.66667           10.641898
# 1244 WORF      275            28.57143           15.177521
# 1245 WESLEY    122            28.40000           16.546903
# 1246 WORF      133            27.63158           14.396028
# 1247 WORF      221            26.33333           32.642230
# 1248 TROI      219            26.00000                  NA
# 1249 WORF      157            25.33333           14.960265
# 1250 BEVERLY   276            21.25000            5.909033
# 1251 WESLEY    132            19.75000           11.461114
# 1252 WESLEY    178            18.66667           11.201190
# 1253 WORF      113            17.75000           14.384598
# 1254 WORF      262            17.75000            7.804913
# 1255 BEVERLY   273            17.00000                  NA
# 1256 WESLEY    104            16.20000           20.644612
# 1257 TROI      239            14.00000                  NA
# 1258 WORF      112            14.00000                  NA
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## Question 1
# In class, we left off on the plot below, which shows the distribution of dialog count by mean dialog length, where each point represents an episode. Interpret these results. How can we tell the character's role in the story by their plot?

# %%
ggplot(dialog_len_per_ep, aes(dialog_count, mean_dialog_length)) + 
    geom_point(aes(color=character)) + 
    facet_wrap(~character)
# Out:
# plot without title

# %% [markdown]
# We can tell the character's role in the story by comparing their dialogue count with their dialogue length. Picard and Riker we are able to identify as main character's since their dialogue count and dialogue length are longer than that of other characters. We can identify Wesley as a minor charcater since he has lower incidence of dialogue count and length.

# %% [markdown]
# ## Question 2
# #### a) Compare Beverly's mean dialog per episode vs. mean dialog count per episode from season 1 (episodes 102-126) to season 3 (episodes 149-174) in a table.
# *Hints*:
# -   First, use `filter()` to get - 1) the dialog from only Beverly's character and 2) the episodes within the ranges given.
# -   Then, add a season variable using `mutate()` with `case_when()`.
# -   To create the means per episode, after your `mutate()` step, you'll need to `group_by()` season and episode number, then you can do your `summarize()` step to get the means by episode. At the end of the `summary()` statement (inside the parenthesis), add `.groups="drop"`.
# -   Then, to get the mean of means, you'll do the same as above, but only grouping by season.

# %%
beverly <- dialog_len_per_ep %>% 
    filter(character=="BEVERLY", 
           (episode_number >= 102 & episode_number <= 126) |
           (episode_number >= 149 & episode_number <= 174)) 

beverly_season <- beverly %>%
    mutate(season = case_when( 
            episode_number >= 102 & episode_number <= 126 ~ "Season 1", 
            episode_number >= 149 & episode_number <= 174 ~ "Season 3"
        ))

beverly_episodes <- beverly_season %>%
  group_by(season, episode_number) %>%
  summarize(
    mean_dialog_length = mean(mean_dialog_length),
    mean_dialog_count = mean(dialog_count),
    .groups = "drop"
  )
beverly_episodes

beverly_summary <- beverly_episodes %>%
  group_by(season) %>%
  summarize(
    mean_dialog_length = mean(mean_dialog_length),
    mean_dialog_count = mean(mean_dialog_count),
    .groups = "drop"
  )

beverly_summary
# Out:
#    season   episode_number mean_dialog_length mean_dialog_count
# 1  Season 1 102             56.74194          31
# 2  Season 1 103             58.82222          45
# 3  Season 1 104             55.64706          17
# 4  Season 1 105             69.20000          10
# 5  Season 1 106             57.54545          11
# 6  Season 1 107             36.60000          10
# 7  Season 1 108             43.63158          57
# 8  Season 1 109             45.73333          30
# 9  Season 1 110             50.25000          52
# 10 Season 1 111             48.00000           9
# 11 Season 1 112             96.13889          36
# 12 Season 1 113             36.80952          21
# 13 Season 1 114             44.52174          23
# 14 Season 1 115             68.69444          36
# 15 Season 1 116            129.71429           7
# 16 Season 1 117             40.56000          25
# 17 Season 1 118             63.60000          30
# 18 Season 1 119             41.44444           9
# 19 Season 1 120             28.80000           5
# 20 Season 1 121             32.25000          16
# 21 Season 1 122             40.88571          35
# 22 Season 1 123             70.82051          39
# 23 Season 1 124             54.41176          34
# 24 Season 1 125             67.92857          14
# 25 Season 1 126             73.36364          33
# 26 Season 3 149             55.28571           7
# 27 Season 3 150             50.32075          53
# 28 Season 3 151             52.88462          26
# 29 Season 3 152             52.37500          16
# 30 Season 3 153             44.38889          18
# 31 Season 3 154             62.83333           6
# 32 Season 3 155             73.38889          36
# 33 Season 3 156             49.40000          10
# 34 Season 3 157             79.30435          23
# 35 Season 3 158             62.16667           6
# 36 Season 3 159            146.50000           2
# 37 Season 3 160             48.69512          82
# 38 Season 3 161             53.00000           9
# 39 Season 3 162             81.00000           2
# 40 Season 3 163             48.83333          12
# 41 Season 3 164            111.77778           9
# 42 Season 3 165             49.81818          11
# 43 Season 3 166             48.80769          26
# 44 Season 3 167             74.60000          10
# 45 Season 3 168             96.71429           7
# 46 Season 3 170             91.14286           7
# 47 Season 3 171             58.91667          24
# 48 Season 3 172             52.75000           8
# 49 Season 3 173             73.80000          75
# 50 Season 3 174             57.50000           6
#   season   mean_dialog_length mean_dialog_count
# 1 Season 1 56.48460           25.40
# 2 Season 3 67.04817           19.64

# %% [markdown]
# #### b) In class, we talked about this character saying the actress has stated that after she was fired and rehired, the writers began giving her storylines that made her feel like a male character. How is this reflected in our table?

# %% [markdown]
# This is reflected in the table since in Season 1, Beverly's character had a lower mean dialogue length and a high mean dialogue count. Therefore, she was speaking more often and in fewer amount of words. However, in Season 3 when she was rehired, she was not speaking as often, but speaking in longer lines. She could have felt like a male character if she perceives that female character's are more chattier and do not speak in monologues.

# %% [markdown]
# ## Question 3
# Let's compare the vocabulary richness (unique words / total words) of each character.
# #### a) Tokenize dialog into words, remove punctuation, convert to lowercase. Then filter out the stop words in the list below (from https://gist.github.com/sebleier/554280).
# *Hint*: Here's a template for that this step should look like:
# ```
# tokens <- YOUR_DATASET %>%
#   # Split each dialog into words
#   mutate(word_list = str_split(DIALOG_COLUMN, "\\s+")) %>%
#
#   # Unnest the list column so each word is a row
#   unnest(word_list) %>%
#
#   # Clean words
#   mutate(
#     word = str_remove_all(word_list, "[[:punct:]]"),  # Remove punctuation
#     word = str_to_lower(word)                         # Convert to lowercase
#   ) %>%
#
#   # Remove empty strings and stopwords
#   filter(word != "", !word %in% STOPWORDS)
# ```

# %%
dialogs_fixed
# Out:
#       episode_number character
# 1     102            PICARD
# 2     102            PICARD
# 3     102            PICARD
# 4     102            PICARD
# 5     102            PICARD
# 6     102            PICARD
# 7     102            PICARD
# 8     102            DATA
# 9     102            PICARD
# 10    102            TROI
# 11    102            PICARD
# 12    102            DATA
# 13    102            PICARD
# 14    102            DATA
# 15    102            PICARD
# 16    102            DATA
# 17    102            PICARD
# 18    102            DATA
# 19    102            TROI
# 20    102            WORF
# 21    102            DATA
# 22    102            TROI
# 23    102            PICARD
# 24    102            WORF
# 25    102            PICARD
# 26    102            PICARD
# 27    102            PICARD
# 28    102            PICARD
# 29    102            PICARD
# 30    102            PICARD
# ⋮     ⋮              ⋮
# 51051 277            PICARD
# 51052 277            WORF
# 51053 277            TROI
# 51054 277            PICARD
# 51055 277            PICARD
# 51056 277            BEVERLY
# 51057 277            TROI
# 51058 277            GEORDI
# 51059 277            RIKER
# 51060 277            RIKER
# 51061 277            BEVERLY
# 51062 277            GEORDI
# 51063 277            DATA
# 51064 277            DATA
# 51065 277            RIKER
# 51066 277            RIKER
# 51067 277            RIKER
# 51068 277            TROI
# 51069 277            RIKER
# 51070 277            TROI
# 51071 277            DATA
# 51072 277            RIKER
# 51073 277            RIKER
# 51074 277            PICARD
# 51075 277            RIKER
# 51076 277            DATA
# 51077 277            PICARD
# 51078 277            PICARD
# 51079 277            TROI
# 51080 277            PICARD
#       dialog
# 1     Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 2     My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 3     ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# 4     I am still somewhat in awe of its size and complexity.
# 5     ... my crew we are short in several key positions, most notably ...
# 6     ... a first officer, but I am informed that a highly experienced man, one Commander William Riker, will be waiting to join our ship when we reach our Cygnus IV destination.
# 7     You will agree, Data, that Starfleet's instructions are difficult?
# 8     Difficult ... how so? Simply solve the mystery of Farpoint Station.
# 9     As simple as that.
# 10    Farpoint Station. Even the name sounds mysterious.
# 11    The problem, Data, is that another life form built that base. How do I negotiate a friendly agreement for Starfleet to use it while at the same time snoop around finding how and why they built it?
# 12    Inquiry ... the word snoop ... ?
# 13    Data, how can you be programmed as a virtual encyclopedia of human information without knowing a simple word like snoop?
# 14    Possibility ... a kind of human behavior I was not designed to emulate?
# 15    It means 'to spy, to sneak' ...
# 16    Ah! To seek covertly, to go stealthily, to slink, slither ...
# 17    Exactly, yes ...
# 18    ... to glide, creep, skulk, pussyfoot, gumshoe ...
# 19    Captain ... I'm sensing a ... a powerful mind ...
# 20    Something strange on the detector circuits ...
# 21    It registers as solid, Captain...
# 22    Or an incredibly powerful forcefield. But if we collide with either ...
# 23    Go to Condition Yellow. And shut off that damned noise.
# 24    Shields and deflectors, up, sir.
# 25    Reverse power, full stop.
# 26    That's quite a directive. Would you mind identifying what you are?
# 27    We call ourselves "the Q". Or you may call me that; it's all much the same thing.
# 28    And I have presented myself to you as a fellow ship captain so that you will better understand me.
# 29    Go back from where you...
# 30    Stay where you are!
# ⋮     ⋮
# 51051 Worf... what's the date?
# 51052 Stardate 47988.
# 51053 Is something wrong, sir?
# 51054 No, no... in fact, I think I'll go back to bed. I could use some sleep.
# 51055 Captain's Log, supplemental. Starfleet Command reports no unusual activity along the Neutral Zone, and there is no sign of a temporal anomaly. It would appear that I am the only member of the crew to retain any knowledge of the events I experienced.
# 51056 That's it for me.
# 51057 There's always next time.
# 51058 That's four hands in a row. How does he do it?
# 51059 I cheat.
# 51060 I'm kidding.
# 51061 I've been thinking... about all the things the Captain told us about the future. The way we changed and drifted apart... why would he tell us what's to come?
# 51062 It sure goes against everything we've heard about not polluting the time line...
# 51063 I believe, however, that this situation is unique.
# 51064 Since the temporal anomaly did not occur, there have already been changes in the way this time line is unfolding. The future we experience will undoubtedly be different from the one the Captain encountered.
# 51065 Maybe that's why he told us. Knowing what that future could bring... gives us a chance to change things now.
# 51066 So that some things never happen.
# 51067 Come in.
# 51068 Am I too late?
# 51069 Not at all. Have a seat.
# 51070 What's the game?
# 51071 Five card draw, deuces wild.
# 51072 Come.
# 51073 Captain. Is there a problem?
# 51074 No. I just thought I might... join you this evening. If there's room...
# 51075 Of course.
# 51076 Would you care to deal?
# 51077 Oh... thank you.
# 51078 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 51079 You were always welcome.
# 51080 So. Five card stud, nothing wild. The sky's the limit.
#       dialog_length
# 1     128
# 2     105
# 3      93
# 4      54
# 5      67
# 6     172
# 7      66
# 8      67
# 9      18
# 10     50
# 11    196
# 12     32
# 13    120
# 14     71
# 15     31
# 16     61
# 17     16
# 18     50
# 19     49
# 20     46
# 21     33
# 22     71
# 23     55
# 24     32
# 25     25
# 26     66
# 27     81
# 28     98
# 29     25
# 30     19
# ⋮     ⋮
# 51051  24
# 51052  15
# 51053  24
# 51054  71
# 51055 249
# 51056  17
# 51057  25
# 51058  46
# 51059   8
# 51060  12
# 51061 157
# 51062  80
# 51063  50
# 51064 206
# 51065 108
# 51066  33
# 51067   8
# 51068  14
# 51069  24
# 51070  16
# 51071  28
# 51072   5
# 51073  28
# 51074  71
# 51075  10
# 51076  23
# 51077  16
# 51078  89
# 51079  24
# 51080  54

# %%
stop_words <- c(
  "i","me","my","myself","we","our","ours","ourselves","you","your","yours","yourself",
  "yourselves","he","him","his","himself","she","her","hers","herself","it","its","itself",
  "they","them","their","theirs","themselves","what","which","who","whom","this","that",
  "these","those","am","is","are","was","were","be","been","being","have","has","had",
  "having","do","does","did","doing","a","an","the","and","but","if","or","because","as",
  "until","while","of","at","by","for","with","about","against","between","into","through",
  "during","before","after","above","below","to","from","up","down","in","out","on","off",
  "over","under","again","further","then","once","here","there","when","where","why","how",
  "all","any","both","each","few","more","most","other","some","such","no","nor","not",
  "only","own","same","so","than","too","very","s","t","can","will","just","don","should","now"
)

tokens <- dialogs_fixed %>%

  mutate(word_list = str_split(dialog, "\\s+")) %>%

  unnest(word_list) %>%

  mutate(
    word = str_remove_all(word_list, "[[:punct:]]"), 
    word = str_to_lower(word)                       
  ) %>%
  
  filter(word != "", !word %in% stop_words)

tokens
# Out:
#        episode_number character
# 1      102            PICARD
# 2      102            PICARD
# 3      102            PICARD
# 4      102            PICARD
# 5      102            PICARD
# 6      102            PICARD
# 7      102            PICARD
# 8      102            PICARD
# 9      102            PICARD
# 10     102            PICARD
# 11     102            PICARD
# 12     102            PICARD
# 13     102            PICARD
# 14     102            PICARD
# 15     102            PICARD
# 16     102            PICARD
# 17     102            PICARD
# 18     102            PICARD
# 19     102            PICARD
# 20     102            PICARD
# 21     102            PICARD
# 22     102            PICARD
# 23     102            PICARD
# 24     102            PICARD
# 25     102            PICARD
# 26     102            PICARD
# 27     102            PICARD
# 28     102            PICARD
# 29     102            PICARD
# 30     102            PICARD
# ⋮      ⋮              ⋮
# 267223 277            PICARD
# 267224 277            PICARD
# 267225 277            PICARD
# 267226 277            PICARD
# 267227 277            PICARD
# 267228 277            PICARD
# 267229 277            RIKER
# 267230 277            DATA
# 267231 277            DATA
# 267232 277            DATA
# 267233 277            PICARD
# 267234 277            PICARD
# 267235 277            PICARD
# 267236 277            PICARD
# 267237 277            PICARD
# 267238 277            PICARD
# 267239 277            PICARD
# 267240 277            PICARD
# 267241 277            PICARD
# 267242 277            PICARD
# 267243 277            PICARD
# 267244 277            TROI
# 267245 277            TROI
# 267246 277            PICARD
# 267247 277            PICARD
# 267248 277            PICARD
# 267249 277            PICARD
# 267250 277            PICARD
# 267251 277            PICARD
# 267252 277            PICARD
#        dialog
# 1      Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 2      Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 3      Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 4      Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 5      Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 6      Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 7      Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 8      Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 9      Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 10     Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 11     Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 12     Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 13     Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 14     Captain's log, stardate 42353.7. Our destination is planet Cygnus IV, beyond which lies the great unexplored mass of the galaxy.
# 15     My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 16     My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 17     My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 18     My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 19     My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 20     My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 21     My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 22     My orders are to examine Farpoint, a starbase built there by the inhabitants of that world. Meanwhile ...
# 23     ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# 24     ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# 25     ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# 26     ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# 27     ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# 28     ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# 29     ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# 30     ... I am becoming better acquainted with my new command, this Galaxy Class U.S.S. Enterprise.
# ⋮      ⋮
# 267223 No. I just thought I might... join you this evening. If there's room...
# 267224 No. I just thought I might... join you this evening. If there's room...
# 267225 No. I just thought I might... join you this evening. If there's room...
# 267226 No. I just thought I might... join you this evening. If there's room...
# 267227 No. I just thought I might... join you this evening. If there's room...
# 267228 No. I just thought I might... join you this evening. If there's room...
# 267229 Of course.
# 267230 Would you care to deal?
# 267231 Would you care to deal?
# 267232 Would you care to deal?
# 267233 Oh... thank you.
# 267234 Oh... thank you.
# 267235 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 267236 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 267237 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 267238 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 267239 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 267240 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 267241 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 267242 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 267243 I should have done this a long time ago. I was quite a card player in my youth, you know.
# 267244 You were always welcome.
# 267245 You were always welcome.
# 267246 So. Five card stud, nothing wild. The sky's the limit.
# 267247 So. Five card stud, nothing wild. The sky's the limit.
# 267248 So. Five card stud, nothing wild. The sky's the limit.
# 267249 So. Five card stud, nothing wild. The sky's the limit.
# 267250 So. Five card stud, nothing wild. The sky's the limit.
# 267251 So. Five card stud, nothing wild. The sky's the limit.
# 267252 So. Five card stud, nothing wild. The sky's the limit.
#        dialog_length word_list   word
# 1      128           Captain's   captains
# 2      128           log,        log
# 3      128           stardate    stardate
# 4      128           42353.7.    423537
# 5      128           destination destination
# 6      128           planet      planet
# 7      128           Cygnus      cygnus
# 8      128           IV,         iv
# 9      128           beyond      beyond
# 10     128           lies        lies
# 11     128           great       great
# 12     128           unexplored  unexplored
# 13     128           mass        mass
# 14     128           galaxy.     galaxy
# 15     105           orders      orders
# 16     105           examine     examine
# 17     105           Farpoint,   farpoint
# 18     105           starbase    starbase
# 19     105           built       built
# 20     105           inhabitants inhabitants
# 21     105           world.      world
# 22     105           Meanwhile   meanwhile
# 23      93           becoming    becoming
# 24      93           better      better
# 25      93           acquainted  acquainted
# 26      93           new         new
# 27      93           command,    command
# 28      93           Galaxy      galaxy
# 29      93           Class       class
# 30      93           U.S.S.      uss
# ⋮      ⋮             ⋮           ⋮
# 267223 71            thought     thought
# 267224 71            might...    might
# 267225 71            join        join
# 267226 71            evening.    evening
# 267227 71            there's     theres
# 267228 71            room...     room
# 267229 10            course.     course
# 267230 23            Would       would
# 267231 23            care        care
# 267232 23            deal?       deal
# 267233 16            Oh...       oh
# 267234 16            thank       thank
# 267235 89            done        done
# 267236 89            long        long
# 267237 89            time        time
# 267238 89            ago.        ago
# 267239 89            quite       quite
# 267240 89            card        card
# 267241 89            player      player
# 267242 89            youth,      youth
# 267243 89            know.       know
# 267244 24            always      always
# 267245 24            welcome.    welcome
# 267246 54            Five        five
# 267247 54            card        card
# 267248 54            stud,       stud
# 267249 54            nothing     nothing
# 267250 54            wild.       wild
# 267251 54            sky's       skys
# 267252 54            limit.      limit

# %% [markdown]
# #### b) Count unique words per character. Print a summary table with the following columns: character, total words, unique words, and vocabulary richness.
# *Hint*: Group by character, then use `summarize()` to get what you want. You'll use `n_distinct()` to get the unique word counts. Arrange in descending value of vocabulary richness.

# %%
uniquechar <- tokens %>% 
    group_by(character) %>% 
    summarise(
        total_words = n(), 
        unique_words = n_distinct(word), 
        vocab_richness = unique_words/ total_words, 
        .groups = "drop" 
        ) %>% 
    arrange(desc(vocab_richness))
        
uniquechar
# Out:
#   character total_words unique_words vocab_richness
# 1 WESLEY     7601       2291         0.3014077
# 2 WORF      18820       4318         0.2294368
# 3 TROI      19450       4187         0.2152699
# 4 BEVERLY   22900       4875         0.2128821
# 5 DATA      45462       8593         0.1890150
# 6 GEORDI    31978       5465         0.1708987
# 7 RIKER     41827       6458         0.1543979
# 8 PICARD    79214       9272         0.1170500

# %% [markdown]
# #### c) Plot total words versus vocab richness.
# -   Use the character names as the "points".
#     -   *Hint*: Use `geom_text()` to add the character names as the points.
# -   Do not include a legend.
#     -   *Hint*: Use `theme()` to remove the legend.
# -   Add a title and axis titles.
#     -   *Hint*: Use `labs()` to add titles.

# %%
installing ggrepel because of overlap of points
# Out:
# Error in parse(text = input): <text>:1:12: unexpected symbol
# 1: installing ggrepel
#                ^
# Traceback:

# %%
install.packages("ggrepel")
library(ggrepel)

ggplot(uniquechar, aes(x = total_words, y = vocab_richness)) +
  geom_text_repel(aes(label = character)) + 
  labs(
    title = "Total Words versus Vocab Richness",
    x = "Total words",
    y = "Vocab richness"
  ) +
  theme(legend.position = "none")
# Out:
# The downloaded binary packages are in
# 	/var/folders/yh/x49cjjwn6w1c2sjv6g2r8ktm0000gn/T//Rtmp417mPq/downloaded_packages
# plot without title

# %% [markdown]
# #### d) Interpret these results.

# %% [markdown]
# Picard used a lot of words out of all of the other characters, yet also had the lowest score for vocab richness, meaning that he likely did not use many unique words in his dialogue. Additionally, Wesley had the highest score for vocab richness, yet had the lowest amount of total words in his dialogue, so he likely had really unique dialogue as a character. The other characters ranged around similar points regarding their total word scores and their vocabulary richness. Specifically, Beverly and Troi almost overlap when plotted because of their similarity.

# %% [markdown]
# ## Question 4
# #### a) Find what episode Wesley left the show as a main character and state it explicitly. Meaning, find the first significant gap where he is not found in more than two episodes in a row.
# *Hint*: It's after season 3 (ended at episode 174), so you can filter out seasons 1-3 and print Wesley's dialog count per episode. Then, scan the table for the gap.

# %%
Wesleyshow <- dialog_len_per_ep %>%
    filter(character=="WESLEY", 
           episode_number > 149) %>% 
    arrange(episode_number)

Wesleyshow

# %% [markdown]
# Wesley leaves the show after episode 183.

# %% [markdown]
# #### b) After Wesley leaves the main cast, in which episodes does he make cameo appearances?

# %% [markdown]
# He makes a cameo appearance in episodes 206, 219, 263, and 272.

# %% [markdown]
# #### c) Dig back into the data. Print:
# -   Wesley's last piece of dialog before he left the main cast.
# -   Wesley's last piece of dialog ever.
#
# *Hint*: To do this, you'll need to filter the `dialogs_fixed` data set to Welsey's lines and the episode number, and use `slice_tail(n = 1)` to get the last observation.

# %%
wesley_dialogue <- dialogs_fixed %>% 
    filter(character=="WESLEY", 
    episode_number == 183) %>%
    slice_tail(n=1) 

wesley_dialogue

wesley_dialogue2 <- dialogs_fixed %>% 
    filter(character=="WESLEY", 
    episode_number == 272) %>%
    slice_tail(n=1) 

wesley_dialogue2
# Out:
#   episode_number character dialog      dialog_length
# 1 183            WESLEY    I can walk. 11
#   episode_number character dialog         dialog_length
# 1 272            WESLEY    Good-bye, Mom. 14

# %% [markdown]
# ## Question 5
# Create a heatmap with `dialog_len_per_ep` showing mean dialog length per episode for each character. Sort the characters on the y-axis by their overall mean dialog length, with the lowest on top using a factor. Add a title and an axis title.
# *Hints*:
# For the factor:
# 1. Compute overall mean (mean of mean) dialog length per character (`group_by()` then `summarize()`), and arrange the overall mean in ascending order. Add `pull(character)` to the end of this step so that you can use character as a factor in the next step. Store all of this in a new tibble.
# 2. Convert character to factor with this order. On `dialog_len_per_ep`, you'll use a mutate statement to add the factor `(mutate(character = factor(character, levels = DATAFROMHINT1))`.
# 3. Create heatmap using `geom_tile()`.
# 4. If you want nicer colors, you can add `scale_fill_viridis_c()` (or another color scale) to your ggplot statement. **Not required**, but fun to mess around with!

# %%
computing <- dialog_len_per_ep %>% 
    group_by(character) %>%
    summarize(overall_mean = mean(mean_dialog_length)) %>% 
    arrange(overall_mean) %>%
    pull(character) 

dialog_len_per_ep <- dialog_len_per_ep %>% 
    mutate(character=factor(character, levels = rev(computing)))

heatmap <- ggplot(dialog_len_per_ep, aes(x=episode_number, y = character, fill = mean_dialog_length)) + 
    geom_tile() + 
    scale_fill_viridis_c() + 
    labs( 
        title = "Mean Dialog Length per Episode by Character", 
        x = "Episode Number", 
        y = "Character"
    ) 
heatmap
# Out:
# plot without title
